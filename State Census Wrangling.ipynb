# %% [markdown]
# **Wrangling State Census Data**

# %%
import numpy as np
import pandas as pd
import os
import missingno as mn

# %%
os.getcwd()
# Out:
# '/Users/phebe/GitHub/Fatal-Police-Shootings-WaPo'

# %%
data = pd.read_csv('../Fatal-Police-Shootings-WaPo/State 2020 Census Race Data.csv')

# %%
df = data.copy()

# %%
df.columns
# Out:
# Index(['Label (Grouping)', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'Puerto Rico'],
#       dtype='object')

# %%
print(df['Label (Grouping)'])
# Out:
# 0                                                Total:
# 1                                    Hispanic or Latino
# 2                               Not Hispanic or Latino:
# 3                               Population of one race:
# 4                                           White alone
#                             ...
# 68                    White; Black or African Americ...
# 69                    White; American Indian and Ala...
# 70                    Black or African American; Ame...
# 71                             Population of six races:
# 72                    White; Black or African Americ...
# Name: Label (Grouping), Length: 73, dtype: object

# %%
df.drop(columns='Puerto Rico', inplace=True)

# %%
df.columns
# Out:
# Index(['Label (Grouping)', 'Alabama', 'Alaska', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho',
#        'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana',
#        'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota',
#        'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada',
#        'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota',
#        'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype='object')

# %%
df.head(10)
# Out:
#                                     Label (Grouping)    Alabama   Alaska  \
# 0                                             Total:  3,917,166  554,003
# 1                                 Hispanic or Latino    166,856   33,441
# 2                            Not Hispanic or Latino:  3,750,310  520,562
# 3                            Population of one race:  3,630,366  477,883
# 4                                        White alone  2,564,544  340,580
# 5                    Black or African American alone    976,732   16,566
# 6              American Indian and Alaska Native ...     18,137   75,017
# 7                                        Asian alone     59,997   34,290
# 8              Native Hawaiian and Other Pacific ...      1,872    8,122
# 9                              Some Other Race alone      9,084    3,308
#
#      Arizona   Arkansas  California   Colorado Connecticut Delaware  \
# 0  5,541,976  2,312,273  30,827,105  4,509,576   2,869,227  783,543
# ...
