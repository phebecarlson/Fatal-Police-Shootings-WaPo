# %%
import pandas as pd 
import numpy as np
import os

# %%
os.getcwd()
# Out:
# '/Users/phebe/GitHub/Fatal-Police-Shootings-WaPo'

# %%
state_data = pd.read_csv('../Fatal-Police-Shootings-WaPo/data/ExtraDFs/state_completed_df.csv')

# %%
percent_state_data = pd.read_csv('../Fatal-Police-Shootings-WaPo/data/state_percent_df.csv')
metro_micro_data = pd.read_csv('../Fatal-Police-Shootings-WaPo/data/MetroMicroAreas/completed_metro-micro_Census.csv')
percent_metro_micro_data = pd.read_csv('../Fatal-Police-Shootings-WaPo/data/MetroMicroAreas/percent-calculated_metro-micro_Census.csv')

# %%
# copy of currently used in Tableau df coord_df_.csv
coord_df_ = pd.read_csv('../Fatal-Police-Shootings-WaPo/data/ExtraDFs/coord_df_.csv')

# %%
state_data
# Out:
#               Unnamed: 0  Total Population  Hispanic or Latino  \
# 0          United States       331449281.0          62080044.0
# 1                Alabama         5024279.0            264047.0
# 2                 Alaska          733391.0             49824.0
# 3                Arizona         7151502.0           2192253.0
# 4               Arkansas         3011524.0            256847.0
# 5             California        39538223.0          15579652.0
# 6               Colorado         5773714.0           1263390.0
# 7            Connecticut         3605944.0            623293.0
# 8               Delaware          989948.0            104290.0
# 9   District of Columbia          689545.0             77652.0
# 10               Florida        21538187.0           5697240.0
# 11               Georgia        10711908.0           1123457.0
# 12                Hawaii         1455271.0            138923.0
# 13                 Idaho         1839106.0            239407.0
# ...

# %%
state_data.rename({'Unnamed: 0':'state_name'}, axis = 'columns', inplace=True)

# %%
state_abbrev = {'United States':' US Total', 'Alabama':'AL', 'Alaska':'AK', 'Arizona':'AZ', 'Arkansas':'AR', 
                'California':'CA','Colorado':'CO', 'Connecticut':'CT', 'Delaware':'DE','District of Columbia':'DC',
                'Florida':'FL', 'Georgia':'GA', 'Hawaii':'HI', 'Idaho':'ID', 'Illinois': 'IL','Indiana': 'IN',
                'Iowa':'IA', 'Kansas':'KS', 'Kentucky':'KY', 'Louisiana':'LA', 'Maine':'ME', 'Maryland':'MD', 
                'Massachusetts':'MA', 'Michigan':'MI', 'Minnesota':'MN', 'Mississippi':'MS', 'Missouri': 'MO',
                'Montana': 'MT', 'Nebraska':'NE', 'Nevada':'NV', 'New Hampshire':'NH','New Jersey':'NJ', 'New Mexico':'NM',
                'New York':'NY', 'North Carolina':'NC', 'North Dakota':'ND','Ohio':'OH','Oklahoma':'OK', 'Oregon':'OR',
                'Pennsylvania':'PA', 'Rhode Island':'RI', 'South Carolina':'SC','South Dakota':'SD','Tennessee':'TN',
                'Texas':'TX', 'Utah':'UT','Vermont':'VT','Virginia':'VA','Washington':'WA', 'West Virginia':'WV',
                'Wisconsin':'WI', 'Wyoming':'WY'}

state_data['state'] = state_data['state_name'].map(state_abbrev)

# %%
state_data
# Out:
#               state_name  Total Population  Hispanic or Latino  \
# 0          United States       331449281.0          62080044.0
# 1                Alabama         5024279.0            264047.0
# 2                 Alaska          733391.0             49824.0
# 3                Arizona         7151502.0           2192253.0
# 4               Arkansas         3011524.0            256847.0
# 5             California        39538223.0          15579652.0
# 6               Colorado         5773714.0           1263390.0
# 7            Connecticut         3605944.0            623293.0
# 8               Delaware          989948.0            104290.0
# 9   District of Columbia          689545.0             77652.0
# 10               Florida        21538187.0           5697240.0
# 11               Georgia        10711908.0           1123457.0
# 12                Hawaii         1455271.0            138923.0
# 13                 Idaho         1839106.0            239407.0
# ...

# %%
# merge
merged = pd.merge(coord_df_, state_data, on=['state', 'state_name'])

# %%
merged.drop(columns='Unnamed: 0', inplace=True)

# %%
merged.columns
# Out:
# Index(['date', 'manner_of_death', 'armed', 'age', 'gender', 'race', 'city',
#        'state', 'signs_of_mental_illness', 'threat_level', 'flee',
#        'body_camera', 'longitude', 'latitude', 'is_geocoding_exact',
#        'age_binned_11_18', 'age_binned_11_15', 'age_binned_7',
#        'age_binned_to_60', 'age_binned_7_diff', 'armed_3', 'armed_4_toy',
#        'armed_4', 'armed_5_toy', 'armed_7', 'count', 'month', 'year',
#        'quarter', 'state_name', 'PopEstimate2015', 'PopEstimate2016',
#        'PopEstimate2017', 'PopEstimate2018', 'PopEstimate2019',
#        'PopEstimate2020', 'PopEstimate2021', 'city/state', 'Total Population',
#        'Hispanic or Latino', 'Not Hispanic or Latino:',
#        'Population of one race:', 'Population of two or more races:',
#        'FRACTotal', 'White Alone and in Combination',
#        'Black Alone and in Combination', 'Asian Alone and in Combination',
#        'Other Alone and in Combination', 'Native Alone and in Combination',
# ...

# %%
merged.drop(columns=['Calc Total (Not Latino)', 'quarter','year','month','PopEstimate2015',
       'PopEstimate2016', 'PopEstimate2017', 'PopEstimate2018', 'PopEstimate2019', 'FRACTotal', 'Not Hispanic or Latino:'],inplace=True)

# %% [markdown]
# # METRO MICRO DATA

# %%
metro_micro_data.rename({'Unnamed: 0':'Location'},axis='columns', inplace=True)

# %%
metro_micro_data
# Out:
#                       Location       Total:  Hispanic or Latino  \
# 0      Aberdeen, SD Micro Area      42287.0              1720.0
# 1      Aberdeen, WA Micro Area      75636.0              7834.0
# 2       Abilene, TX Metro Area     176579.0             41566.0
# 3           Ada, OK Micro Area      38065.0              2208.0
# 4        Adrian, MI Micro Area      99423.0              8494.0
# ..                         ...          ...                 ...
# 935   Yuba City, CA Metro Area     181208.0             55088.0
# 936        Yuma, AZ Metro Area     203881.0            130003.0
# 937  Zanesville, OH Micro Area      86410.0              1055.0
# 938      Zapata, TX Micro Area      13889.0             12999.0
# 939              United States  331449281.0          62080044.0
#
#      Not Hispanic or Latino:  Population of one race:  \
# 0                    40567.0                  39254.0
# 1                    67802.0                  63097.0
# ...

# %%
metro_micro_data.drop(columns=['Calc Total (Not Latino)','FRACTotal', 'Not Hispanic or Latino:'], inplace=True)

# %%
state_abbrev = {'United States':' US Total', 'Alabama':'AL', 'Alaska':'AK', 'Arizona':'AZ', 'Arkansas':'AR', 
                'California':'CA','Colorado':'CO', 'Connecticut':'CT', 'Delaware':'DE','District of Columbia':'DC',
                'Florida':'FL', 'Georgia':'GA', 'Hawaii':'HI', 'Idaho':'ID', 'Illinois': 'IL','Indiana': 'IN',
                'Iowa':'IA', 'Kansas':'KS', 'Kentucky':'KY', 'Louisiana':'LA', 'Maine':'ME', 'Maryland':'MD', 
                'Massachusetts':'MA', 'Michigan':'MI', 'Minnesota':'MN', 'Mississippi':'MS', 'Missouri': 'MO',
                'Montana': 'MT', 'Nebraska':'NE', 'Nevada':'NV', 'New Hampshire':'NH','New Jersey':'NJ', 'New Mexico':'NM',
                'New York':'NY', 'North Carolina':'NC', 'North Dakota':'ND','Ohio':'OH','Oklahoma':'OK', 'Oregon':'OR',
                'Pennsylvania':'PA', 'Rhode Island':'RI', 'South Carolina':'SC','South Dakota':'SD','Tennessee':'TN',
                'Texas':'TX', 'Utah':'UT','Vermont':'VT','Virginia':'VA','Washington':'WA', 'West Virginia':'WV',
                'Wisconsin':'WI', 'Wyoming':'WY'}
state_data['state'] = state_data['state_name'].map(state_abbrev)

# %%
metro_micro_data['state'] = 0

# %%
abbrevs = {'AL', 'AK','AZ','AR','CA','CO','CT','DE','DC','FL','GA','HI', 'ID','IL','IN',
          'IA','KS','KY','LA','ME','MD','MA','MI','MN','MS','MO', 'MT','NE','NV', 'NH','NJ','NM','NY','NC','ND','OH',
          'OK','OR','PA','RI', 'SC','SD','TN','TX','UT','VT','VA','WA','WV','WI','WY'}


for i in range(len(metro_micro_data['Location'])):
    place=metro_micro_data['Location'][i]
    #print(place)
    for abbrev in abbrevs:
        if abbrev in place:
            #print(abbrev)
            metro_micro_data['state'][i] = abbrev
        #print(metro_micro_data['state'][i])
       # if a in place:
            #print(a)
            #metro_micro_data.loc[place] = a
# Out:
# /var/folders/v_/wdytmqyx1377p1m8yrz0tdrr0000gn/T/ipykernel_1733/2677946164.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metro_micro_data['state'][i] = abbrev

# %%
metro_micro_data['state'].iloc[939] = 'US Total'

# %%
metro_micro_data['city'] = ''

# %%
for i in range(len(metro_micro_data['Location'])):
    place=metro_micro_data['Location'][i]
    #print(place)
    city=metro_micro_data['Location'][i].split(',')[0]
    metro_micro_data['city'][i] = city
        #print(metro_micro_data['state'][i])
       # if a in place:
            #print(a)
            #metro_micro_data.loc[place] = a
# Out:
# /var/folders/v_/wdytmqyx1377p1m8yrz0tdrr0000gn/T/ipykernel_1733/2437365135.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metro_micro_data['city'][i] = city

# %%
metro_micro_data.rename({'Total:':'Total Population'},axis='columns',inplace=True)

# %%
metro_micro_data
# Out:
#                       Location  Total Population  Hispanic or Latino  \
# 0      Aberdeen, SD Micro Area           42287.0              1720.0
# 1      Aberdeen, WA Micro Area           75636.0              7834.0
# 2       Abilene, TX Metro Area          176579.0             41566.0
# 3           Ada, OK Micro Area           38065.0              2208.0
# 4        Adrian, MI Micro Area           99423.0              8494.0
# ..                         ...               ...                 ...
# 935   Yuba City, CA Metro Area          181208.0             55088.0
# 936        Yuma, AZ Metro Area          203881.0            130003.0
# 937  Zanesville, OH Micro Area           86410.0              1055.0
# 938      Zapata, TX Micro Area           13889.0             12999.0
# 939              United States       331449281.0          62080044.0
#
#      Population of one race:  Population of two or more races:  \
# 0                    39254.0                            1313.0
# ...

# %%
# add NHPI to Asian for comparison sake accounts for 0.18% of population
metro_micro_data['Asian/NHPI Alone and in Combination'] = metro_micro_data['Asian Alone and in Combination'] + metro_micro_data['NHPI Alone and in Combination']

# %%
metro_micro_data
# Out:
#                       Location  Total Population  Hispanic or Latino  \
# 0      Aberdeen, SD Micro Area           42287.0              1720.0
# 1      Aberdeen, WA Micro Area           75636.0              7834.0
# 2       Abilene, TX Metro Area          176579.0             41566.0
# 3           Ada, OK Micro Area           38065.0              2208.0
# 4        Adrian, MI Micro Area           99423.0              8494.0
# ..                         ...               ...                 ...
# 935   Yuba City, CA Metro Area          181208.0             55088.0
# 936        Yuma, AZ Metro Area          203881.0            130003.0
# 937  Zanesville, OH Micro Area           86410.0              1055.0
# 938      Zapata, TX Micro Area           13889.0             12999.0
# 939              United States       331449281.0          62080044.0
#
#      Population of one race:  Population of two or more races:  \
# 0                    39254.0                            1313.0
# ...

# %%
# merge
metro_merge = pd.merge(coord_df_, metro_micro_data, on=['state','city'])

# %%
merged
# Out:
#             date   manner_of_death       armed  age gender      race  \
# 0     2015-01-02              shot         gun   53      M     Asian
# 1     2015-02-10  tasered and shot     unarmed   35      M  Hispanic
# 2     2015-03-19              shot     unarmed   20      M     White
# 3     2015-04-21              shot     unarmed   37      M    Native
# 4     2015-05-04              shot  toy weapon   36      M     White
# ...          ...               ...         ...  ...    ...       ...
# 7798  2016-06-13              shot         gun   80      M  Hispanic
# 7799  2017-11-09              shot     Unknown   32      M     White
# 7800  2018-09-07              shot         gun   28      M     Black
# 7801  2021-11-22              shot         gun   32      M      None
# 7802  2022-04-27              shot     vehicle   58      M      None
#
#             city state  signs_of_mental_illness threat_level  ...  \
# 0        Shelton    WA                     True       attack  ...
# ...

# %%
metro_merge['city']
# Out:
# 0           Shelton
# 1           Shelton
# 2            Yakima
# 3            Yakima
# 4            Yakima
#            ...
# 1502    Sioux Falls
# 1503    Sioux Falls
# 1504    Sioux Falls
# 1505        Rutland
# 1506        Rutland
# Name: city, Length: 1507, dtype: object

# %%
state_metro_micro = pd.merge(state_data, metro_micro_data, on=['state'], suffixes=['_state', '_area'])

# %%
state_metro_micro
# Out:
#     state_name  Total Population_state  Hispanic or Latino_state  \
# 0      Alabama               5024279.0                  264047.0
# 1      Alabama               5024279.0                  264047.0
# 2      Alabama               5024279.0                  264047.0
# 3      Alabama               5024279.0                  264047.0
# 4      Alabama               5024279.0                  264047.0
# ..         ...                     ...                       ...
# 922    Wyoming                576851.0                   59046.0
# 923    Wyoming                576851.0                   59046.0
# 924    Wyoming                576851.0                   59046.0
# 925    Wyoming                576851.0                   59046.0
# 926    Wyoming                576851.0                   59046.0
#
#      Not Hispanic or Latino:  Population of one race:_state  \
# 0                  4760232.0                      4575614.0
# 1                  4760232.0                      4575614.0
# ...

# %%
merged.to_csv(f'coord_df_STATE.csv')

# %%
metro_micro_data.to_csv(f'completed_metro-micro_Census.csv')
metro_merge.to_csv(f'coord_df_METRO_MICRO.csv')
state_metro_micro.to_csv(f'state_metro_micro_merged.csv')
